# %% [markdown]
# # <center>Assessment CLO-3: Tugas Pemrograman Learning</center>

# %% [markdown]
# <b>Topik</b>
# [Klasifikasi/Regresi] pada [nama dataset] menggunakan [nama metode]]
#
# <b>Kelompok: </b>
#
# Anggota:
# 1. Nama - NIM
# 2. Nama - NIM
# 3. Nama - NIM

# %% [markdown]
# #### Pendahuluan
# Silahkan double click cell ini dan perkenalkan dataset yang Anda pilih, beserta masalah apa yang ingin diselesaikan!
#
# Jelaskan pula bagaimana Anda mengolah data serta membaginya untuk tahap training dan testing!

# %%
# Importing the tools we
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# Show your data in tabular or other visualization ways
# Data Preprocessing
# Data Splitting
# Write your code here

# Reading and printing the data head
data = pd.read_csv("abalone.data", header=None)
column_names = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings']
df = pd.DataFrame(data)
df.columns = column_names
print(df.head())

# Making a histogram in the target variable which is the "Rings" variable
df["Rings"].hist()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7
# <Axes: >

# %%
# Making the data correlation
numeric_columns = df.select_dtypes(include='number')
corr = numeric_columns.corr(method="pearson")
cmap = sns.diverging_palette(250, 10, as_cmap=True)
sns.heatmap(corr, vmax=1, vmin=-1, cmap=cmap, square=True, linewidths=0.2)
# Out:
# <Axes: >

# %%
data = df[["Length", "Height", "Whole_weight", "Rings"]]
data.head(10)
# Out:
#    Length  Height  Whole_weight  Rings
# 0   0.455   0.095        0.5140     15
# 1   0.350   0.090        0.2255      7
# 2   0.530   0.135        0.6770      9
# 3   0.440   0.125        0.5160     10
# 4   0.330   0.080        0.2050      7
# 5   0.425   0.095        0.3515      8
# 6   0.530   0.150        0.7775     20
# 7   0.545   0.125        0.7680     16
# 8   0.475   0.125        0.5095      9
# 9   0.550   0.150        0.8945     19

# %%
fig, axes = plt.subplots(1, 3, figsize = (18,6), sharey = True)
sns.histplot(df, ax=axes[0], x="Length", kde=True, color='r')
sns.histplot(df, ax=axes[1], x="Height", kde=True, color='b')
sns.histplot(df, ax=axes[2], x="Whole_weight", kde=True)
# Out:
# <Axes: xlabel='Whole_weight', ylabel='Count'>

# %% [markdown]
# #### Metode yang Digunakan
# Silahkan double click cell ini dan jelaskan metode yang Anda pilih, disertai penjelasan mengenai setting parameter yang ditentukan!

# %%
# Experiment Settings
# Write your code here

# %%
# Model Training
# Save the trained model
# Write your code here

# %%
# Model Testing and Evaluation
# Show the performance
# Write your code here

# %% [markdown]
# #### Hasil dan Analisis
# Silahkan double click cell ini dan tulis hasil dan analisis!
#
# Tampilkan performa yang dihasilkan, bisa dalam tabel dan grafik, diukur berdasarkan metrik evaluasi yang dipakai.
#
# Tuliskan hasil analisis Anda.

# %% [markdown]
# #### Kesimpulan
# Silahkan double click cell ini dan tulis kesimpulan berdasarkan hasil percobaan yang Anda lakukan!
